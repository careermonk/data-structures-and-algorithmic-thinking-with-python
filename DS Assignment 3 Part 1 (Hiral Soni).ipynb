# %%
#Linked List


import math

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
    
class LinkedList:
    def __init__(self):
        self.head = None
    
    def addToList(self,data):
        newNode = Node(data)
        
        if self.head == None: #first node
            self.head = newNode
            
        else: #traverse to end of list
            current = self.head
            
            while current.next is not None:
                current = current.next
            current.next = newNode
            
        
    
    def __str__(self):
        if self.head == None:
            return "Empty List"
        current = self.head
        temp = str(current.data)
        while current.next is not None:
            current = current.next
            temp = temp + " -->"+str(current.data)
        return temp



# Find Modular Node            
            
    def findMod(self,k):
        curr = self.head
        modNode = None
        n = 1
        
        if k <= 0 and self.head is None:
            return None
        
        while curr:
            
            if n%k == 0:
                modNode = curr
                #print(n,k,"::",n%k)
            curr = curr.next
            n = n+1
        return modNode.data
    
  # Square Root Node

  
    def findSqrtNode(self) : 
        
        temp = None
        i = 1
        j = 1
        curr = self.head
        while curr: 

            if (i == j*j) : 
                if (temp == None) : 
                    temp = self.head  
                else: 
                    temp = temp.next
                j = j + 1         
            i = i + 1
          
            curr = curr.next
        return temp.data
       
            
        
            
        
        


# Debug Code        
                        
if __name__ == '__main__':
    l1 = LinkedList()
    l1.addToList(10)
    l1.addToList(40)
    l1.addToList(20)
    l1.addToList(30)
    print('Linked List ::\n',l1,'\n')

    print('Modular Node ::',l1.findMod(2))
    print('SquareRoot Node ::',l1.findSqrtNode())
# Out:
# Linked List ::
#  10 -->40 -->20 -->30
#
# Modular Node :: 30
# SquareRoot Node :: 40
